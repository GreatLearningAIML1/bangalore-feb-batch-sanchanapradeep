# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(X_train, Y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train = tf.keras.utils.to_categorical(Y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
model = tf.keras.models.Sequential()
#Reshape data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

#Normalize the data
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Add second convolutional layer
model.add(tf.keras.layers.Dense(200, 
                                activation='relu'))
#Add second convolutional layer
model.add(tf.keras.layers.Dense(100, 
                                activation='relu'))

#Add another dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(tf.keras.layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train,
                          epochs=10,validation_data=(X_test,y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.5085 - acc: 0.8175 - val_loss: 0.4007 - val_acc: 0.8564
# Epoch 2/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.3970 - acc: 0.8553 - val_loss: 0.4015 - val_acc: 0.8607
# Epoch 3/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.3593 - acc: 0.8685 - val_loss: 0.3509 - val_acc: 0.8739
# Epoch 4/10
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.3324 - acc: 0.8777 - val_loss: 0.3496 - val_acc: 0.8765
# Epoch 5/10
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.3128 - acc: 0.8861 - val_loss: 0.3665 - val_acc: 0.8754
# Epoch 6/10
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.2972 - acc: 0.8881 - val_loss: 0.3619 - val_acc: 0.8779
# Epoch 7/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.2841 - acc: 0.8938 - val_loss: 0.3971 - val_acc: 0.8734
# Epoch 8/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.2727 - acc: 0.8977 - val_loss: 0.3500 - val_acc: 0.8863
# Epoch 9/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.2600 - acc: 0.9028 - val_loss: 0.3717 - val_acc: 0.8865
# Epoch 10/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.2514 - acc: 0.9044 - val_loss: 0.4051 - val_acc: 0.8833
